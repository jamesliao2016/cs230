# %% [markdown]
# https://machinelearningmastery.com/check-point-deep-learning-models-keras/

# %%
# Checkpoint the weights when validation accuracy improves
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-3bf8d9b5e243> in <module>
#       1 # Checkpoint the weights when validation accuracy improves
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import Dense
#       4 from keras.callbacks import ModelCheckpoint
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'keras'

# %%
# fix random seed for reproducibility
numpy.random.seed(7)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_acc improved from -inf to 0.67323, saving model to weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_acc did not improve from 0.67323
#
# Epoch 00003: val_acc did not improve from 0.67323
#
# Epoch 00004: val_acc improved from 0.67323 to 0.69685, saving model to weights-improvement-04-0.70.hdf5
#
# Epoch 00005: val_acc did not improve from 0.69685
#
# Epoch 00006: val_acc improved from 0.69685 to 0.69685, saving model to weights-improvement-06-0.70.hdf5
#
# Epoch 00007: val_acc did not improve from 0.69685
#
# Epoch 00008: val_acc did not improve from 0.69685
#
# Epoch 00009: val_acc did not improve from 0.69685
#
# Epoch 00010: val_acc did not improve from 0.69685
#
# Epoch 00011: val_acc did not improve from 0.69685
#
# Epoch 00012: val_acc did not improve from 0.69685
#
# Epoch 00013: val_acc did not improve from 0.69685
#
# Epoch 00014: val_acc did not improve from 0.69685
#
# Epoch 00015: val_acc did not improve from 0.69685
#
# Epoch 00016: val_acc did not improve from 0.69685
#
# Epoch 00017: val_acc did not improve from 0.69685
#
# Epoch 00018: val_acc did not improve from 0.69685
#
# Epoch 00019: val_acc did not improve from 0.69685
#
# Epoch 00020: val_acc did not improve from 0.69685
#
# Epoch 00021: val_acc did not improve from 0.69685
#
# Epoch 00022: val_acc did not improve from 0.69685
#
# Epoch 00023: val_acc did not improve from 0.69685
#
# Epoch 00024: val_acc did not improve from 0.69685
#
# Epoch 00025: val_acc did not improve from 0.69685
#
# Epoch 00026: val_acc did not improve from 0.69685
#
# Epoch 00027: val_acc did not improve from 0.69685
#
# Epoch 00028: val_acc did not improve from 0.69685
#
# Epoch 00029: val_acc did not improve from 0.69685
#
# Epoch 00030: val_acc did not improve from 0.69685
#
# Epoch 00031: val_acc did not improve from 0.69685
#
# Epoch 00032: val_acc did not improve from 0.69685
#
# Epoch 00033: val_acc did not improve from 0.69685
#
# Epoch 00034: val_acc did not improve from 0.69685
#
# Epoch 00035: val_acc did not improve from 0.69685
#
# Epoch 00036: val_acc did not improve from 0.69685
#
# Epoch 00037: val_acc improved from 0.69685 to 0.71654, saving model to weights-improvement-37-0.72.hdf5
#
# Epoch 00038: val_acc did not improve from 0.71654
#
# Epoch 00039: val_acc did not improve from 0.71654
#
# Epoch 00040: val_acc did not improve from 0.71654
#
# Epoch 00041: val_acc did not improve from 0.71654
#
# Epoch 00042: val_acc did not improve from 0.71654
#
# Epoch 00043: val_acc did not improve from 0.71654
#
# Epoch 00044: val_acc did not improve from 0.71654
#
# Epoch 00045: val_acc did not improve from 0.71654
#
# Epoch 00046: val_acc did not improve from 0.71654
#
# Epoch 00047: val_acc improved from 0.71654 to 0.72835, saving model to weights-improvement-47-0.73.hdf5
#
# Epoch 00048: val_acc did not improve from 0.72835
#
# Epoch 00049: val_acc did not improve from 0.72835
#
# Epoch 00050: val_acc did not improve from 0.72835
#
# Epoch 00051: val_acc did not improve from 0.72835
#
# Epoch 00052: val_acc did not improve from 0.72835
#
# Epoch 00053: val_acc improved from 0.72835 to 0.74409, saving model to weights-improvement-53-0.74.hdf5
#
# Epoch 00054: val_acc did not improve from 0.74409
#
# Epoch 00055: val_acc did not improve from 0.74409
#
# Epoch 00056: val_acc did not improve from 0.74409
#
# Epoch 00057: val_acc did not improve from 0.74409
#
# Epoch 00058: val_acc did not improve from 0.74409
#
# Epoch 00059: val_acc did not improve from 0.74409
#
# Epoch 00060: val_acc did not improve from 0.74409
#
# Epoch 00061: val_acc did not improve from 0.74409
#
# Epoch 00062: val_acc did not improve from 0.74409
#
# Epoch 00063: val_acc did not improve from 0.74409
#
# Epoch 00064: val_acc improved from 0.74409 to 0.74803, saving model to weights-improvement-64-0.75.hdf5
#
# Epoch 00065: val_acc did not improve from 0.74803
#
# Epoch 00066: val_acc did not improve from 0.74803
#
# Epoch 00067: val_acc did not improve from 0.74803
#
# Epoch 00068: val_acc did not improve from 0.74803
#
# Epoch 00069: val_acc did not improve from 0.74803
#
# Epoch 00070: val_acc did not improve from 0.74803
#
# Epoch 00071: val_acc did not improve from 0.74803
#
# Epoch 00072: val_acc improved from 0.74803 to 0.76378, saving model to weights-improvement-72-0.76.hdf5
#
# Epoch 00073: val_acc did not improve from 0.76378
#
# Epoch 00074: val_acc did not improve from 0.76378
#
# Epoch 00075: val_acc did not improve from 0.76378
#
# Epoch 00076: val_acc did not improve from 0.76378
#
# Epoch 00077: val_acc did not improve from 0.76378
#
# Epoch 00078: val_acc did not improve from 0.76378
#
# Epoch 00079: val_acc did not improve from 0.76378
#
# Epoch 00080: val_acc did not improve from 0.76378
#
# Epoch 00081: val_acc did not improve from 0.76378
#
# Epoch 00082: val_acc did not improve from 0.76378
#
# Epoch 00083: val_acc did not improve from 0.76378
#
# Epoch 00084: val_acc did not improve from 0.76378
#
# Epoch 00085: val_acc did not improve from 0.76378
#
# Epoch 00086: val_acc did not improve from 0.76378
#
# Epoch 00087: val_acc did not improve from 0.76378
#
# Epoch 00088: val_acc did not improve from 0.76378
#
# Epoch 00089: val_acc did not improve from 0.76378
#
# Epoch 00090: val_acc did not improve from 0.76378
#
# Epoch 00091: val_acc did not improve from 0.76378
#
# Epoch 00092: val_acc did not improve from 0.76378
#
# Epoch 00093: val_acc did not improve from 0.76378
#
# Epoch 00094: val_acc improved from 0.76378 to 0.76772, saving model to weights-improvement-94-0.77.hdf5
#
# Epoch 00095: val_acc did not improve from 0.76772
#
# Epoch 00096: val_acc did not improve from 0.76772
#
# Epoch 00097: val_acc did not improve from 0.76772
#
# Epoch 00098: val_acc did not improve from 0.76772
#
# Epoch 00099: val_acc did not improve from 0.76772
#
# Epoch 00100: val_acc improved from 0.76772 to 0.77953, saving model to weights-improvement-100-0.78.hdf5
#
# Epoch 00101: val_acc did not improve from 0.77953
#
# Epoch 00102: val_acc did not improve from 0.77953
#
# Epoch 00103: val_acc did not improve from 0.77953
#
# Epoch 00104: val_acc did not improve from 0.77953
#
# Epoch 00105: val_acc did not improve from 0.77953
#
# Epoch 00106: val_acc did not improve from 0.77953
#
# Epoch 00107: val_acc did not improve from 0.77953
#
# Epoch 00108: val_acc did not improve from 0.77953
#
# Epoch 00109: val_acc improved from 0.77953 to 0.79134, saving model to weights-improvement-109-0.79.hdf5
#
# Epoch 00110: val_acc did not improve from 0.79134
#
# Epoch 00111: val_acc did not improve from 0.79134
#
# Epoch 00112: val_acc did not improve from 0.79134
#
# Epoch 00113: val_acc did not improve from 0.79134
#
# Epoch 00114: val_acc did not improve from 0.79134
#
# Epoch 00115: val_acc did not improve from 0.79134
#
# Epoch 00116: val_acc did not improve from 0.79134
#
# Epoch 00117: val_acc did not improve from 0.79134
#
# Epoch 00118: val_acc did not improve from 0.79134
#
# Epoch 00119: val_acc did not improve from 0.79134
#
# Epoch 00120: val_acc did not improve from 0.79134
#
# Epoch 00121: val_acc did not improve from 0.79134
#
# Epoch 00122: val_acc did not improve from 0.79134
#
# Epoch 00123: val_acc did not improve from 0.79134
#
# Epoch 00124: val_acc did not improve from 0.79134
#
# Epoch 00125: val_acc did not improve from 0.79134
#
# Epoch 00126: val_acc did not improve from 0.79134
#
# Epoch 00127: val_acc did not improve from 0.79134
#
# Epoch 00128: val_acc did not improve from 0.79134
#
# Epoch 00129: val_acc did not improve from 0.79134
#
# Epoch 00130: val_acc did not improve from 0.79134
#
# Epoch 00131: val_acc did not improve from 0.79134
#
# Epoch 00132: val_acc did not improve from 0.79134
#
# Epoch 00133: val_acc did not improve from 0.79134
#
# Epoch 00134: val_acc did not improve from 0.79134
#
# Epoch 00135: val_acc did not improve from 0.79134
#
# Epoch 00136: val_acc did not improve from 0.79134
#
# Epoch 00137: val_acc did not improve from 0.79134
#
# Epoch 00138: val_acc did not improve from 0.79134
#
# Epoch 00139: val_acc did not improve from 0.79134
#
# Epoch 00140: val_acc did not improve from 0.79134
#
# Epoch 00141: val_acc did not improve from 0.79134
#
# Epoch 00142: val_acc did not improve from 0.79134
#
# Epoch 00143: val_acc did not improve from 0.79134
#
# Epoch 00144: val_acc did not improve from 0.79134
#
# Epoch 00145: val_acc did not improve from 0.79134
#
# Epoch 00146: val_acc did not improve from 0.79134
#
# Epoch 00147: val_acc did not improve from 0.79134
#
# Epoch 00148: val_acc did not improve from 0.79134
#
# Epoch 00149: val_acc did not improve from 0.79134
#
# Epoch 00150: val_acc did not improve from 0.79134
